# %% [markdown]
# # Banaketa Jarraituak
#
# ### Helburua:
# Banaketa diskretuak eta jarraituen arteko harremana ikusi

# %%
x1=16:65
#x2= c(15:35, 46:65)
x1x2= seq(15, 65, by=.1)
plot(x1x2, dnorm(x1x2, 40, sqrt(24)), type="l",xlab="x", ylab="Banaketa Binomialaren Probabilitateak")
#lines(x2, dbinom(x2, 100, .4), type="h", col=2)
lines(x1, dbinom(x1, 100, .4), type="h", lwd=2)
# Out:
# plot without title

# %% [markdown]
# ### Azalpena:
#
# Goiko irudiko lerroek n=100 eta p=0.4 parametrodun banaketa binomialaren banaketa funtzioa adierazten dute. Ikusten da funtzio jarraitu baten gertukoa dela.
